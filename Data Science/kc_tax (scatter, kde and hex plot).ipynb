# %%
cd Studying/Data
# Out:
# /Users/ivankudravcev/Studying/Data

# %%
ls
# Out:
# States.csv             dfw_airlines.csv       president_heights.csv
# airlines.csv           kc_tax.csv             seattle2014.csv
# airlines.numbers       mprun_demo.py          sp500_data.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

df = pd.read_csv('//Users/ivankudravcev/Studying/Data/kc_tax.csv')
df = df[df['TaxAssessedValue'] < 750000]
df = df[df['SqFtTotLiving'] > 100]
df = df[df['SqFtTotLiving'] < 3500]
df
# Out:
#         TaxAssessedValue  SqFtTotLiving  ZipCode
# 1               206000.0           1870  98002.0
# 2               303000.0           1530  98166.0
# 3               361000.0           2000  98108.0
# 4               459000.0           3150  98108.0
# 5               223000.0           1570  98032.0
# ...                  ...            ...      ...
# 498244          375000.0           2230  98056.0
# 498245          316000.0           1710  98056.0
# 498246          340000.0           1930  98056.0
# 498247          132000.0           2930  98056.0
# 498248          286000.0           1310  98056.0
#
# [432693 rows x 3 columns]

# %%
# HEX PLOT
hx = sns.jointplot(data=df, x='SqFtTotLiving', y='TaxAssessedValue', kind='hex')
plt.show()

# KDE PLOT
kde = sns.kdeplot(x=df['SqFtTotLiving'], y=df['TaxAssessedValue'], cmap="Reds", shade=True, thresh=0)
plt.show()

# %%
# ALL UNIQUE VALUES IN VARIABLE (COLUMN 'ZipCode')
zips = np.array(df['ZipCode'].dropna().unique(), dtype=int)
zips
# Out:
# array([   98002,    98166,    98108,    98032,    98168,    98055,
#           98122,    98116,    98007,    98052,    98038,    98146,
#           98178,    98118,    98059,    98008,    98075,    98042,
#           98092,    98010,    98051,    98198,    98065,    98117,
#           98058,    98126,    98106,    98027,    98177,    98045,
#           98136,    98144,    98022,    98030,    98188,    98040,
#           98033,    98028,    98072,    98107,    98014,    98133,
#           98224,    98005,    98115,    98053,    98155,    98001,
#           98034,    98023,    98109,    98031,    98077,    98056,
#           98004,    98148,    98003,    98199,    98019,    98103,
#           98125,    98070,    98006,    98105,    98102,    98068,
#           98011,    98029,    98047,    98074,    98112,    98024,
#           98119,    98057,    98288,    98354,    98422,    98050,
#           98204,    98134,       98,    98039,    95059,    98113,
# ...

# %%
# WHERE IS THE MOST EXPENSIVE SQUARE Ft TOTAL LIVING?

max_tax_ind=np.argmax(df['TaxAssessedValue'])
df.iloc[max_tax_ind]
# Out:
# TaxAssessedValue    749000.0
# SqFtTotLiving         2930.0
# ZipCode              98075.0
# Name: 112, dtype: float64

# %%
# SCATTER & HEX PLOT AT ZIPCODE 98075 (THE MOST EXPENSIVE PLACE)
sns.jointplot(data=df[df['ZipCode']==98075], x='SqFtTotLiving', y='TaxAssessedValue', kind='scatter')
sns.jointplot(data=df[df['ZipCode']==98075], x='SqFtTotLiving', y='TaxAssessedValue', kind='hex')
