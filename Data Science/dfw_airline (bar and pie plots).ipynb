# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

df = pd.read_csv('//Users/ivankudravcev/Studying/Data/dfw_airlines.csv')
labels = str.split(df.columns[0], sep=';')
labels.remove(labels[-1])

data = str.split(df.values[0][0], sep=';')
data.remove(data[-1])
    

plt.figure(figsize=(10,10))
plt.title('REASONS FOR FLIGHT DELAY ("PIE" PLOT)')
plt.pie(data, labels=labels)
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.title('REASONS FOR FLIGHT DELAY (BAR PLOT)')
sns.barplot(x=labels, y=data_to_float)
# Out:
# <AxesSubplot:title={'center':'REASONS FOR FLIGHT DELAY (BAR PLOT)'}>
