# %%
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

df = pd.read_csv('/Users/ivankudravcev/Studying/Data/sp500_data.csv')

stats.probplot(df['NFLX'], dist='norm', plot = plt)
plt.show()
