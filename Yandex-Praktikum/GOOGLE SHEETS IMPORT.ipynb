# %% [markdown]
# Импортируем скачанный датасет (например с портала открытых данных) в Google Sheets.
# Настраиваем общий доступ (для всех) и копируем ссылку
#
# https://docs.google.com/spreadsheets/d/1z5Bhbts10fwFIHCpTPxxdBFfUeBYbgYrSvofaTvj-iI/edit?usp=sharing
#
# Часть ссылки __1z5Bhbts10fwFIHCpTPxxdBFfUeBYbgYrSvofaTvj-iI__ – это идентификатор таблицы.
# К

# %%
import pandas as pd
from io import BytesIO
import requests
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
spreadsheet_id = '1z5Bhbts10fwFIHCpTPxxdBFfUeBYbgYrSvofaTvj-iI'
file_name = 'https://docs.google.com/spreadsheets/d/{}/export?format=csv'.format(spreadsheet_id)
r = requests.get(file_name)
df = pd.read_csv(BytesIO(r.content))
df.head()
# Out:
#           ID                                               Name  global_id  \
# 0        Код                                       Наименование  global_id
# 1   00151635                                            СМЕТАНА  637376221
# 2  000077874                                             Родник  637376331
# 3  000024309                                    Кафе «Академия»  637376349
# 4  000027429  ГБОУ «Школа № 1430 имени Героя Социалистическо...  637376480
#
#         IsNetObject               OperatingCompany   TypeObject  \
# 0  Является сетевым  Название управляющей компании  Вид объекта
# 1               нет                            NaN         кафе
# 2               нет                            NaN         кафе
# 3               нет                            NaN     ресторан
# 4               нет                            NaN     столовая
#
#                                    AdmArea           District  \
# 0         Административный округ по адресу              Район
# ...

# %%
columns = df.columns
columns
# Out:
# Index(['ID', 'Name', 'global_id', 'IsNetObject', 'OperatingCompany',
#        'TypeObject', 'AdmArea', 'District', 'Address', 'PublicPhone',
#        'SeatsCount', 'SocialPrivileges', 'Longitude_WGS84', 'Latitude_WGS84',
#        'ID_en', 'Name_en', 'IsNetObject_en', 'OperatingCompany_en',
#        'TypeObject_en', 'AdmArea_en', 'District_en', 'Address_en',
#        'PublicPhone_en', 'SeatsCount_en', 'SocialPrivileges_en',
#        'Longitude_WGS84_en', 'Latitude_WGS84_en', 'geodata_center', 'geoarea'],
#       dtype='object')
